# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importando Dados...

# %%
DF_matriculas = pd.read_csv("https://raw.githubusercontent.com/Guardians-DSC/dados/main/desempenho_academico/dados_brutos/matriculas.csv")
DF_disciplinas = pd.read_csv("https://raw.githubusercontent.com/Guardians-DSC/dados/main/desempenho_academico/dados_brutos/disciplinas.csv")

# %% [markdown]
# O objetivo dessa análise é verificar o desempenho acadêmico dos alunos nas disciplinas de:
# "PROJETO DE SOFTWARE"
# "ENGENHARIA DE SOFTWARE"
# "PROJETO EM COMPUTACAO I"
# "PROJETO EM COMPUTACAO II"

# %% [markdown]
# #Recuperando Códigos das disciplinas

# %% [markdown]
# ---
#
#
# PROJETO DE SOFTWARE

# %%
psoft = DF_disciplinas[DF_disciplinas["name"]=="PROJETO DE SOFTWARE"]
psoft
# Out:
#     courseCode  curriculumCode  subjectCode  academicUnitId  credits  hours  \
# 18    14102100            2017      1411308            1411        4     60
#
#                    name equivalentCodes  idealTerm  preRequirements  \
# 18  PROJETO DE SOFTWARE         1411178          4  1411167,1411180
#
#     coRequirements type
# 18             NaN    M

# %%
code_psoft = psoft["subjectCode"][18]
print("CÓDIGO:", code_psoft)
# Out:
# CÓDIGO: 1411308

# %% [markdown]
# ---
#
#
# ENGENHARIA DE SOFTWARE

# %%
esoft = DF_disciplinas[DF_disciplinas["name"]=="ENGENHARIA DE SOFTWARE"]
esoft
# Out:
#     courseCode  curriculumCode  subjectCode  academicUnitId  credits  hours  \
# 21    14102100            2017      1411314            1411        4     60
#
#                       name equivalentCodes  idealTerm  preRequirements  \
# 21  ENGENHARIA DE SOFTWARE         1411177          5  1411167,1411180
#
#     coRequirements type
# 21             NaN    M

# %%
code_esoft = esoft["subjectCode"][21]
print("CÓDIGO:", code_esoft)
# Out:
# CÓDIGO: 1411314

# %% [markdown]
# ---
#
#
# PROJETO EM COMPUTACÃO I

# %%
projeto1 = DF_disciplinas[DF_disciplinas["name"]=="PROJETO EM COMPUTACAO I"]
projeto1
# Out:
#      courseCode  curriculumCode  subjectCode  academicUnitId  credits  hours  \
# 195    14102100            1999      1411185            1411        4     60
#
#                         name equivalentCodes  idealTerm preRequirements  \
# 195  PROJETO EM COMPUTACAO I             NaN          7             NaN
#
#      coRequirements type
# 195             NaN    M

# %%
code_projeto1 = projeto1["subjectCode"][195]
print("CÓDIGO:", code_projeto1)
# Out:
# CÓDIGO: 1411185

# %% [markdown]
# ---
#
#
# PROJETO EM COMPUTAÇÃO II

# %%
projeto2 = DF_disciplinas[DF_disciplinas["name"]=="PROJETO EM COMPUTACAO II"]
projeto2
# Out:
#      courseCode  curriculumCode  subjectCode  academicUnitId  credits  hours  \
# 196    14102100            1999      1411186            1411        6     90
#
#                          name equivalentCodes  idealTerm preRequirements  \
# 196  PROJETO EM COMPUTACAO II             NaN          8             NaN
#
#      coRequirements type
# 196             NaN    M

# %%
code_projeto2 = projeto2['subjectCode'][196]
print("CÓDIGO:", code_projeto2)
# Out:
# CÓDIGO: 1411186

# %% [markdown]
# #Agrupando Matriculas por Disciplina e Período

# %% [markdown]
# ---
#
#
# PROJETO DE SOFTWARE

# %%
matriculas_psoft = DF_matriculas[DF_matriculas["subjectCode"] == code_psoft]
matriculas_psoft.head()
# Out:
#         subjectCode    term  classId  credits grade    status
# 116453      1411308  2018.1        0        4   5,0  Dispensa
# 116454      1411308  2018.1        0        4   5,0  Dispensa
# 116455      1411308  2018.1        0        4   5,0  Dispensa
# 116456      1411308  2018.1        0        4   5,1  Dispensa
# 116457      1411308  2018.1        0        4   5,1  Dispensa

# %%
# Agrupando apenas o periodo da pandemia
mat_psoft_pandemia = matriculas_psoft[(matriculas_psoft['term'] >= 2020.1) & (matriculas_psoft['term'] < 2023.1)]
mat_psoft_pandemia
# Out:
#         subjectCode    term  classId  credits grade    status
# 116963      1411308  2020.1        1        4     -  Trancado
# 116964      1411308  2020.1        1        4     -  Trancado
# 116965      1411308  2020.1        1        4     -  Trancado
# 116966      1411308  2020.1        1        4     -  Trancado
# 116967      1411308  2020.1        1        4     -  Trancado
# ...             ...     ...      ...      ...   ...       ...
# 117374      1411308  2022.2        2        4   7,8  Aprovado
# 117375      1411308  2022.2        2        4   7,8  Aprovado
# 117376      1411308  2022.2        2        4   8,3  Aprovado
# 117377      1411308  2022.2        2        4   8,4  Aprovado
# 117378      1411308  2022.2        2        4   8,9  Aprovado
#
# [416 rows x 6 columns]

# %% [markdown]
# ---
#
# ENGENHARIA DE SOFTWARE

# %%
matriculas_esoft = DF_matriculas[DF_matriculas["subjectCode"] == code_esoft]
matriculas_esoft.head()
# Out:
#         subjectCode    term  classId  credits grade    status
# 122995      1411314  2018.1        0        4   5,0  Dispensa
# 122996      1411314  2018.1        0        4   5,0  Dispensa
# 122997      1411314  2018.1        0        4   5,2  Dispensa
# 122998      1411314  2018.1        0        4   5,2  Dispensa
# 122999      1411314  2018.1        0        4   5,3  Dispensa

# %%
# Agrupado pelo periodo da pandemia
mat_esoft_pandemia = matriculas_esoft[(matriculas_esoft['term'] >= 2020.1) & (matriculas_esoft['term'] < 2023.1)]
mat_esoft_pandemia
# Out:
#         subjectCode    term  classId  credits grade     status
# 123351      1411314  2020.1        1        4   0,0  Reprovado
# 123352      1411314  2020.1        1        4   7,2   Aprovado
# 123353      1411314  2020.1        1        4   7,4   Aprovado
# 123354      1411314  2020.1        1        4   7,6   Aprovado
# 123355      1411314  2020.1        1        4   8,1   Aprovado
# ...             ...     ...      ...      ...   ...        ...
# 123740      1411314  2022.2        1        4   9,4   Aprovado
# 123741      1411314  2022.2        1        4   9,4   Aprovado
# 123742      1411314  2022.2        1        4   9,5   Aprovado
# 123743      1411314  2022.2        1        4   9,6   Aprovado
# 123744      1411314  2022.2        1        4   9,7   Aprovado
#
# [394 rows x 6 columns]

# %% [markdown]
# ---
#
# PROJETO EM COMPUTACAO I

# %%
matriculas_projeto1 = DF_matriculas[DF_matriculas["subjectCode"] == code_projeto1]
matriculas_projeto1.head()
# Out:
#        subjectCode    term  classId  credits grade    status
# 84390      1411185  2000.1        0        4   9,0  Aprovado
# 84391      1411185  2000.2        0        4     -  Trancado
# 84392      1411185  2000.2        0        4     -  Trancado
# 84393      1411185  2000.2        0        4     -  Trancado
# 84394      1411185  2000.2        0        4     -  Trancado

# %%
# Agrupando pelo periodo da pandemia
mat_projeto1_pandemia = matriculas_projeto1[(matriculas_projeto1['term'] >= 2020.1) & (matriculas_projeto1['term'] < 2023.1)]
mat_projeto1_pandemia
# Out:
#        subjectCode    term  classId  credits grade    status
# 85520      1411185  2020.1        1        4     -  Trancado
# 85521      1411185  2020.1        1        4     -  Trancado
# 85522      1411185  2020.1        1        4   7,0  Aprovado
# 85523      1411185  2020.1        1        4   8,7  Aprovado
# 85524      1411185  2020.1        1        4   8,7  Aprovado
# ...            ...     ...      ...      ...   ...       ...
# 85827      1411185  2022.2        1        4   9,7  Aprovado
# 85828      1411185  2022.2        1        4   9,7  Aprovado
# 85829      1411185  2022.2        1        4   9,7  Aprovado
# 85830      1411185  2022.2        1        4   9,7  Aprovado
# 85831      1411185  2022.2        1        4   9,7  Aprovado
#
# [312 rows x 6 columns]

# %% [markdown]
# ---
#
# PROJETO EM COMPUTAÇÃO 2

# %%
matriculas_projeto2 = DF_matriculas[DF_matriculas["subjectCode"] == code_projeto2]
matriculas_projeto2.head()
# Out:
#        subjectCode    term  classId  credits grade    status
# 85832      1411186  2000.2        0        6     -  Trancado
# 85833      1411186  2001.1        0        6  10,0  Aprovado
# 85834      1411186  2001.1        0        6   7,5  Aprovado
# 85835      1411186  2001.1        0        6   7,5  Aprovado
# 85836      1411186  2001.1        0        6   7,5  Aprovado

# %%
# Agrupando pelo periodo da pandemia
mat_projeto2_pandemia = matriculas_projeto2[(matriculas_projeto2['term'] >= 2020.1) & (matriculas_projeto2['term'] < 2023.1)]
mat_projeto2_pandemia
# Out:
#        subjectCode    term  classId  credits grade    status
# 86727      1411186  2020.1        1        6   8,4  Aprovado

# %% [markdown]
# #Gerando Vizualização

# %%
x = (mat_psoft_pandemia['status'] == "Aprovado").value_counts()[True]
plt.bar(x, 3)
plt.show()
